# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\salary\salary.csv")
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17872\1038048182.py:1: DtypeWarning: Columns (16,18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\HP\Downloads\salary\salary.csv")
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# ...

# %% [markdown]
# ## Basic checks

# %%
df.shape
# Out:
# (149481, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149481 entries, 0 to 149480
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   AGENCY                   149481 non-null  int64
#  1   AGENCY NAME              149481 non-null  object
#  2   LAST NAME                149481 non-null  object
#  3   FIRST NAME               149481 non-null  object
#  4   MI                       149481 non-null  object
#  5   CLASS CODE               149481 non-null  object
#  6   CLASS TITLE              149481 non-null  object
#  7   ETHNICITY                149481 non-null  object
#  8   GENDER                   149481 non-null  object
#  9   STATUS                   149481 non-null  object
#  10  EMPLOY DATE              149481 non-null  object
#  11  HRLY RATE                149481 non-null  float64
#  12  HRS PER WK               149481 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# AGENCY                          0
# AGENCY NAME                     0
# LAST NAME                       0
# FIRST NAME                      0
# MI                              0
# CLASS CODE                      0
# CLASS TITLE                     0
# ETHNICITY                       0
# GENDER                          0
# STATUS                          0
# EMPLOY DATE                     0
# HRLY RATE                       0
# HRS PER WK                      0
# MONTHLY                         0
# ANNUAL                          0
# STATE NUMBER                    0
# duplicated                 149338
# multiple_full_time_jobs    149467
# combined_multiple_jobs     149384
# summed_annual_salary       149465
# hide_from_search           149465
# dtype: int64

# %%
# We can see last five columns contain nearly all the null values

# %%
df.describe()
# Out:
#               AGENCY      HRLY RATE     HRS PER WK        MONTHLY  \
# count  149481.000000  149481.000000  149481.000000  149481.000000
# mean      545.736288       0.346488      39.714918    4226.184248
# std       139.057691       4.211485       2.323855    2093.111691
# min       101.000000       0.000000       1.000000      50.000000
# 25%       529.000000       0.000000      40.000000    3019.840000
# 50%       530.000000       0.000000      40.000000    3720.170000
# 75%       696.000000       0.000000      40.000000    4865.810000
# max       930.000000     117.788480      70.000000   46125.000000
#
#               ANNUAL  STATE NUMBER  multiple_full_time_jobs  \
# count  149481.000000  1.494810e+05                     14.0
# mean    50714.210973  5.651930e+05                      1.0
# std     25117.340292  4.786212e+05                      0.0
# min       600.000000  1.000000e+00                      1.0
# 25%     36238.080000  1.133340e+05                      1.0
# ...

# %%
df.AGENCY.nunique()
# Out:
# 113

# %%
df.ETHNICITY.unique()
# Out:
# array(['WHITE          ', 'HISPANIC       ', 'BLACK          ',
#        'OTHER          ', 'AM INDIAN      ', 'ASIAN          '],
#       dtype=object)

# %%
df["STATE NUMBER"].nunique()
# Out:
# 149465

# %%
df.hide_from_search.value_counts()
# Out:
# hide_from_search
# True    16
# Name: count, dtype: int64

# %%
df["CLASS TITLE"].unique()
# Out:
# array(['JUDGE, RETIRED                                    ',
#        'GENERAL COUNSEL IV                                ',
#        'CORREC  OFFICER IV                                ', ...,
#        'CURATOR III                                       ',
#        'CURATOR IV                                        ',
#        'EQUIPMENT MAINT TECH I                            '], dtype=object)

# %%
pd.set_option("display.max_columns",None)

# %%
df.shape
# Out:
# (149481, 21)

# %%
df.summed_annual_salary
# Out:
# 0         131407.08
# 1               NaN
# 2         131407.08
# 3               NaN
# 4               NaN
#             ...
# 149476          NaN
# 149477          NaN
# 149478          NaN
# 149479          NaN
# 149480          NaN
# Name: summed_annual_salary, Length: 149481, dtype: float64

# %%
df.STATUS.unique()
# Out:
# array(['URP - UNCLASSIFIED REGULAR PART-TIME    ',
#        'CTP - CLASSIFIED TEMPORARY PART-TIME    ',
#        'CRF - CLASSIFIED REGULAR FULL-TIME      ',
#        'ERP - EXEMPT REGULAR PART-TIME          ',
#        'CRP - CLASSIFIED REGULAR PART-TIME      ',
#        'URF - UNCLASSIFIED REGULAR FULL-TIME    ',
#        'CTP - CLASSIFIED TEMPORARY FULL-TIME    ',
#        'UTF - UNCLASSIFIED TEMPORARY FULL-TIME  ',
#        'UTP - UNCLASSIFIED TEMPORARY PART-TIME  ',
#        'ERF - EXEMPT REGULAR FULL-TIME          ',
#        'CTF - CLASSIFIED TEMPORARY FULL-TIME    '], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['AGENCY', 'AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY DATE',
#        'HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL', 'STATE NUMBER',
#        'duplicated', 'multiple_full_time_jobs', 'combined_multiple_jobs',
#        'summed_annual_salary', 'hide_from_search'],
#       dtype='object')

# %%
df.head()
# Out:
#    AGENCY                                        AGENCY NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
# 2     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3     212  OFFICE OF COURT ADMINISTRATION                ...
# 4     696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
#
#                         LAST NAME                      FIRST NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
# 2  SPECIA JR                       JOHN                            J
# 3  SPECIA JR                       JOHN                            J
# 4  ONTIVEROS                       ESTHER
#
#   CLASS CODE                                        CLASS TITLE  \
# 0   JD25      JUDGE, RETIRED                                ...
# 1   3524      GENERAL COUNSEL IV                            ...
# ...

# %%
sns.barplot(x=df.ETHNICITY , y= df.ANNUAL )
plt.show()

# %%
sns.barplot(x=df.GENDER , y= df.ANNUAL )
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.barplot(x=df.STATUS , y= df.ANNUAL )
plt.show()

# %%
df["ANNUAL"].describe()
# Out:
# count    149481.000000
# mean      50714.210973
# std       25117.340292
# min         600.000000
# 25%       36238.080000
# 50%       44642.040000
# 75%       58389.720000
# max      553500.000000
# Name: ANNUAL, dtype: float64

# %%
sns.displot(df.ANNUAL)
plt.show()

# %%
IQR= 58389.720000 - 36238.080000

# %%
lower_limit= 36238.080000 - 1.5 * IQR
upper_limit= 58389.720000  + 1.5 * IQR

# %%
print(lower_limit)
print(upper_limit)
# Out:
# 3010.6200000000026
# 91617.18

# %%
Outlier_in_salaries = df[(df['ANNUAL']>91617.18) | (df['ANNUAL']<3010.6200000000026)]['CLASS TITLE'].unique()
(Outlier_in_salaries.tolist())
# Out:
# ['JUDGE, RETIRED                                    ',
#  'DIRECTOR IV                                       ',
#  'LEG. OFFICIAL/ADMINISTRATOR                       ',
#  'LEGISLATIVE PROFESSIONAL                          ',
#  'COMMITTEE DIRECTOR                                ',
#  'ELECTED OFFICIALS STAFF                           ',
#  'DIRECTOR II                                       ',
#  'PROGRAM SUPERVISOR VII                            ',
#  'DIRECTOR VI                                       ',
#  'MGR V                                             ',
#  'DIRECTOR V                                        ',
#  'ARCHITECT IV                                      ',
#  'SPECIAL COUNSEL                                   ',
#  'MGR, COMPUTER SUPPORT CENTER                      ',
#  'EXEC DIRECTOR                                     ',
#  'DEPUTY DIR, LEGAL                                 ',
#  'PROGRAMMER V                                      ',
# ...

# %%
df.head()
# Out:
#    AGENCY                                        AGENCY NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
# 2     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3     212  OFFICE OF COURT ADMINISTRATION                ...
# 4     696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
#
#                         LAST NAME                      FIRST NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
# 2  SPECIA JR                       JOHN                            J
# 3  SPECIA JR                       JOHN                            J
# 4  ONTIVEROS                       ESTHER
#
#   CLASS CODE                                        CLASS TITLE  \
# 0   JD25      JUDGE, RETIRED                                ...
# 1   3524      GENERAL COUNSEL IV                            ...
# ...

# %%
df["AGENCY NAME"].nunique()
# Out:
# 113

# %%
df.groupby

# %%
df["CLASS TITLE"]
# Out:
# 0         JUDGE, RETIRED                                ...
# 1         GENERAL COUNSEL IV                            ...
# 2         JUDGE, RETIRED                                ...
# 3         GENERAL COUNSEL IV                            ...
# 4         CORREC  OFFICER IV                            ...
#                                 ...
# 149476    SECURITY OFFICER III                          ...
# 149477    WEB ADMINISTRATOR III                         ...
# 149478    CUSTOMER SERVICE REP I                        ...
# 149479    PROGRAM SPECIALIST III                        ...
# 149480    CUSTOMER SERVICE REP I                        ...
# Name: CLASS TITLE, Length: 149481, dtype: object

# %%
df.STATUS.unique()
# Out:
# array(['URP - UNCLASSIFIED REGULAR PART-TIME    ',
#        'CTP - CLASSIFIED TEMPORARY PART-TIME    ',
#        'CRF - CLASSIFIED REGULAR FULL-TIME      ',
#        'ERP - EXEMPT REGULAR PART-TIME          ',
#        'CRP - CLASSIFIED REGULAR PART-TIME      ',
#        'URF - UNCLASSIFIED REGULAR FULL-TIME    ',
#        'CTP - CLASSIFIED TEMPORARY FULL-TIME    ',
#        'UTF - UNCLASSIFIED TEMPORARY FULL-TIME  ',
#        'UTP - UNCLASSIFIED TEMPORARY PART-TIME  ',
#        'ERF - EXEMPT REGULAR FULL-TIME          ',
#        'CTF - CLASSIFIED TEMPORARY FULL-TIME    '], dtype=object)

# %%
df.pivot_table(values = ['ANNUAL'], index = ['CLASS TITLE','STATUS'], aggfunc = 'median')
# Out:
#                                                                                                ANNUAL
# CLASS TITLE                                        STATUS
# 14 CUSTOMER SERVICES REP                           URF - UNCLASSIFIED REGULAR FULL-TIME      40008.00
# 19 EXECUTIVE ASSISTANT                             URF - UNCLASSIFIED REGULAR FULL-TIME      64992.96
# 20 PROGRAM SPECIALIST III                          URF - UNCLASSIFIED REGULAR FULL-TIME      60136.32
# 21 BUSINESS ANALYST                                URF - UNCLASSIFIED REGULAR FULL-TIME      66414.72
# 21 SYSTEMS ADMINISTRATOR III                       URF - UNCLASSIFIED REGULAR FULL-TIME      58375.02
# ...                                                                                               ...
# WRITING SPEC I                                     URF - UNCLASSIFIED REGULAR FULL-TIME      39249.96
# WRITING SPEC II                                    URF - UNCLASSIFIED REGULAR FULL-TIME      42999.96
# ...

# %%
df["AGENCY NAME"].nunique()
# Out:
# 113

# %%
df.pivot_table(values = ['ANNUAL'], index = ["AGENCY NAME",'CLASS TITLE','STATUS'], aggfunc = 'median')
# Out:
#                                                                                                                                                   ANNUAL
# AGENCY NAME                                        CLASS TITLE                                        STATUS
# ALCOHOLIC BEVERAGE COMMISSION                      ACCOUNTANT I                                       CRF - CLASSIFIED REGULAR FULL-TIME        39000.00
#                                                    ACCOUNTANT II                                      CRF - CLASSIFIED REGULAR FULL-TIME        42500.04
#                                                    ACCOUNTANT IV                                      CRF - CLASSIFIED REGULAR FULL-TIME        51000.00
#                                                    ACCOUNTANT VI                                      CRF - CLASSIFIED REGULAR FULL-TIME        63543.48
# ...

# %%
df.pivot_table(values = ['ANNUAL'], index = ["AGENCY NAME",'EMPLOY DATE' ,'CLASS TITLE','STATUS'], aggfunc = 'median')
# Out:
#                                                                                                                                                                ANNUAL
# AGENCY NAME                                        EMPLOY DATE CLASS TITLE                                        STATUS
# ALCOHOLIC BEVERAGE COMMISSION                      01/01/09    SGT, TABC                                          CRF - CLASSIFIED REGULAR FULL-TIME         77638.92
#                                                    01/01/17    TRAINING SPEC IV                                   CRF - CLASSIFIED REGULAR FULL-TIME         57999.96
#                                                    01/01/18    LICENSE AND PERMIT SPEC II                         CRF - CLASSIFIED REGULAR FULL-TIME         38692.08
#                                                    01/01/20    BUSINESS ANALYST II                                CRF - CLASSIFIED REGULAR FULL-TIME         59004.00
# ...
